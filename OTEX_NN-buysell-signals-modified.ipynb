# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import requests
from pandas.compat import StringIO
#Getting stock data
def get_eod_data(symbol, api_token='5cb671b0b4a790.35526238', session=None):
    if session is None:
        session = requests.Session()
        url = 'https://eodhistoricaldata.com/api/eod/%s' % symbol
        params = {'api_token': api_token}
        r = session.get(url, params=params)
        if r.status_code == requests.codes.ok:
            df = pd.read_csv(StringIO(r.text), skipfooter=1, parse_dates=[0],)
            return df
        else:
            raise Exception(r.status_code, r.reason, url)

# %%
df = get_eod_data('OTEX.US') #Using Microsoft Stock
df=df[df['Date'].dt.year==2019]
#df=df[df['Date'].dt.month == 5]
date_ori = pd.to_datetime(df.iloc[:, 0]).tolist() #时间
df.head()
# Out:
# C:\Users\zliu2\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   # This is added back by InteractiveShellApp.init_path()
#            Date   Open    High      Low  Close  Adjusted_close  Volume
# 5774 2019-01-02  32.10  32.531  31.9800  32.43         32.1656  449014
# 5775 2019-01-03  32.18  32.360  31.4300  31.45         31.1936  311478
# 5776 2019-01-04  31.91  32.320  31.7900  32.21         31.9474  335399
# 5777 2019-01-07  32.22  32.860  32.0400  32.76         32.4929  464218
# 5778 2019-01-08  33.05  33.810  32.8003  33.71         33.4351  567192

# %%
close = df.Close.values.tolist() #选取收盘数据做测试
initial_money = 3000 
window_size = 30 
skip = 1

# %%
#define classes for neural net
class neuralnetwork:
    def __init__(self, id_, hidden_size = 128):
        self.W1 = np.random.randn(window_size, hidden_size) / np.sqrt(window_size)
        self.W2 = np.random.randn(hidden_size, 3) / np.sqrt(hidden_size)
        self.fitness = 0
        self.id = id_    #output

def relu(X):
    return np.maximum(X, 0)    #Rectified Linear Unit - activation function
    
def softmax(X):
    e_x = np.exp(X - np.max(X, axis=-1, keepdims=True))   #Exponential
    return e_x / np.sum(e_x, axis=-1, keepdims=True)      #Exponential divided by the exponential of whole y axis

def feed_forward(X, nets):
    a1 = np.dot(X, nets.W1)
    z1 = relu(a1)
    a2 = np.dot(z1, nets.W2)
    return softmax(a2)

# %%
class NeuroEvolution:
    def __init__(self, population_size, mutation_rate, model_generator,  
                state_size, window_size, trend, skip, initial_money):    
        self.population_size = population_size 
        self.mutation_rate = mutation_rate
        self.model_generator = model_generator
        self.state_size = state_size #状态空间
        self.window_size = window_size #滑动窗口大小
        self.half_window = window_size // 2
        self.trend = trend #data
        self.skip = skip #采取动作的步长，1代表每个时刻都操作
        self.initial_money = initial_money
        
    def _initialize_population(self):
        self.population = []
        for i in range(self.population_size):
            self.population.append(self.model_generator(i))
    
    #变异（定义如何随机挑选0-1互换的位置）
    def mutate(self, individual, scale=1.0):
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W1.shape)
        individual.W1 += np.random.normal(loc=0, scale=scale, size=individual.W1.shape) * mutation_mask
        mutation_mask = np.random.binomial(1, p=self.mutation_rate, size=individual.W2.shape)
        individual.W2 += np.random.normal(loc=0, scale=scale, size=individual.W2.shape) * mutation_mask
        return individual
    
    def inherit_weights(self, parent, child):
        child.W1 = parent.W1.copy()
        child.W2 = parent.W2.copy()
        return child
    
    #父母的DNA交叉配对(定义到底怎么个交叉法)
    def crossover(self, parent1, parent2):
        child1 = self.model_generator((parent1.id+1)*10)
        child1 = self.inherit_weights(parent1, child1)
        child2 = self.model_generator((parent2.id+1)*10)
        child2 = self.inherit_weights(parent2, child2)
        # first W
        n_neurons = child1.W1.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W1[:, cutoff:] = parent2.W1[:, cutoff:].copy()
        child2.W1[:, cutoff:] = parent1.W1[:, cutoff:].copy()
        # second W
        n_neurons = child1.W2.shape[1]
        cutoff = np.random.randint(0, n_neurons)
        child1.W2[:, cutoff:] = parent2.W2[:, cutoff:].copy()
        child2.W2[:, cutoff:] = parent1.W2[:, cutoff:].copy()
        return child1, child2
    
    def get_state(self, t): #某t时刻的状态
        window_size = self.window_size + 1
        d = t - window_size + 1 
        #早期天数不够窗口打小，用0时刻来凑，即填补相应个数
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])#每步收益
        return np.array([res]) #作为状态编码
    
    def act(self, p, state):
        logits = feed_forward(state, p)
        return np.argmax(logits, 1)[0]
    
    def buy(self, individual):
        initial_money = self.initial_money #启动资金
        starting_money = initial_money
        state = self.get_state(0)#初始状态
        inventory = []
        states_sell = []
        states_buy = []
        
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(individual, state)#根据状态选动作
            next_state = self.get_state(t + 1)#得到下一个状态
            #action=1为买入，资金够用，且剩下的长度足够
            if action == 1 and starting_money >= self.trend[t]:
                inventory.append(self.trend[t])#买入
                initial_money -= self.trend[t]#交易
                states_buy.append(t)#记录
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
            #action=2为卖出
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)#卖出
                initial_money += self.trend[t] #交易
                states_sell.append(t)#记录
                try:
                    invest = ((self.trend[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, self.trend[t], invest, initial_money)
                )
            #下一状态
            state = next_state
        #计算收益
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
    
    def calculate_fitness(self):
        for i in range(self.population_size):
            initial_money = self.initial_money
            starting_money = initial_money
            state = self.get_state(0)
            inventory = [] #仓位
            
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(self.population[i], state)
                next_state = self.get_state(t + 1)
            
                if action == 1 and starting_money >= self.trend[t]:
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]

                elif action == 2 and len(inventory):
                    bought_price = inventory.pop(0)
                    starting_money += self.trend[t]

                state = next_state
            invest = ((starting_money - initial_money) / initial_money) * 100
            self.population[i].fitness = invest
    
    def evolve(self, generations=20, checkpoint= 5):
        self._initialize_population()
        n_winners = int(self.population_size * 0.4)
        n_parents = self.population_size - n_winners
        for epoch in range(generations):
            self.calculate_fitness() #计算适应度得分，适应度越高的越好
            fitnesses = [i.fitness for i in self.population]
            sort_fitness = np.argsort(fitnesses)[::-1]
            self.population = [self.population[i] for i in sort_fitness]
            fittest_individual = self.population[0]
            if (epoch+1) % checkpoint == 0:
                print('epoch %d, fittest individual %d with accuracy %f'%(epoch+1, sort_fitness[0], 
                                                                          fittest_individual.fitness))
            next_population = [self.population[i] for i in range(n_winners)]
            total_fitness = np.sum([np.abs(i.fitness) for i in self.population])
            parent_probabilities = [np.abs(i.fitness / total_fitness) for i in self.population]
            parents = np.random.choice(self.population, size=n_parents, p=parent_probabilities, replace=False)
            #对于种群中所有个体，在种群中挑选另一个体进行配对
            for i in np.arange(0, len(parents), 2):
                child1, child2 = self.crossover(parents[i], parents[i+1])
                next_population += [self.mutate(child1), self.mutate(child2)]
            self.population = next_population
        return fittest_individual

# %%
population_size = 150 #种群的个体数目
generations = 100 #有多少代（主循环的迭代次数）
mutation_rate = 0.1 #变异的概率/强度
neural_evolve = NeuroEvolution(population_size, mutation_rate, neuralnetwork,
                              window_size, window_size, close, skip, initial_money)

# %%
fittest_nets = neural_evolve.evolve(60) #change from 75 to 60
# Out:
# epoch 5, fittest individual 0 with accuracy 1.177667
# epoch 10, fittest individual 0 with accuracy 1.177667
# epoch 15, fittest individual 0 with accuracy 1.366000
# epoch 20, fittest individual 0 with accuracy 1.366000
# epoch 25, fittest individual 0 with accuracy 1.366000
# epoch 30, fittest individual 0 with accuracy 1.366000
# epoch 35, fittest individual 0 with accuracy 1.366000
# epoch 40, fittest individual 0 with accuracy 1.366000
# epoch 45, fittest individual 0 with accuracy 1.366000
# epoch 50, fittest individual 0 with accuracy 1.366000
# epoch 55, fittest individual 101 with accuracy 1.380000
# epoch 60, fittest individual 0 with accuracy 1.380000

# %%
states_buy, states_sell, total_gains, invest = neural_evolve.buy(fittest_nets)
# Out:
# day 2: buy 1 unit at price 32.210000, total balance 2967.790000
# day 3: buy 1 unit at price 32.760000, total balance 2935.030000
# day 4, sell 1 unit at price 33.710000, investment 4.656939 %, total balance 2968.740000,
# day 6: buy 1 unit at price 34.470000, total balance 2934.270000
# day 7: buy 1 unit at price 34.490000, total balance 2899.780000
# day 8: buy 1 unit at price 34.270000, total balance 2865.510000
# day 9: buy 1 unit at price 34.410000, total balance 2831.100000
# day 10: buy 1 unit at price 34.500000, total balance 2796.600000
# day 12: buy 1 unit at price 35.290000, total balance 2761.310000
# day 13, sell 1 unit at price 34.780000, investment 6.166056 %, total balance 2796.090000,
# day 14: buy 1 unit at price 34.970000, total balance 2761.120000
# day 15: buy 1 unit at price 35.230000, total balance 2725.890000
# day 16: buy 1 unit at price 35.810000, total balance 2690.080000
# day 17, sell 1 unit at price 35.500000, investment 2.988106 %, total balance 2725.580000,
# day 18, sell 1 unit at price 35.090000, investment 1.739635 %, total balance 2760.670000,
# day 19: buy 1 unit at price 35.270000, total balance 2725.400000
# day 20: buy 1 unit at price 35.640000, total balance 2689.760000
# day 23, sell 1 unit at price 37.690000, investment 9.979574 %, total balance 2727.450000,
# day 24: buy 1 unit at price 37.480000, total balance 2689.970000
# day 25: buy 1 unit at price 36.940000, total balance 2653.030000
# day 26: buy 1 unit at price 37.030000, total balance 2616.000000
# day 27, sell 1 unit at price 36.700000, investment 6.655042 %, total balance 2652.700000,
# day 28, sell 1 unit at price 36.860000, investment 6.840580 %, total balance 2689.560000,
# day 29, sell 1 unit at price 37.060000, investment 5.015585 %, total balance 2726.620000,
# day 30, sell 1 unit at price 37.410000, investment 6.977409 %, total balance 2764.030000,
# day 32: buy 1 unit at price 37.540000, total balance 2726.490000
# day 33: buy 1 unit at price 37.680000, total balance 2688.810000
# day 34, sell 1 unit at price 37.410000, investment 6.187908 %, total balance 2726.220000,
# day 35, sell 1 unit at price 37.890000, investment 5.808433 %, total balance 2764.110000,
# day 36: buy 1 unit at price 38.080000, total balance 2726.030000
# day 37: buy 1 unit at price 38.200000, total balance 2687.830000
# day 38: buy 1 unit at price 38.370000, total balance 2649.460000
# day 39, sell 1 unit at price 37.920000, investment 7.513468 %, total balance 2687.380000,
# day 40, sell 1 unit at price 38.070000, investment 6.818182 %, total balance 2725.450000,
# day 41, sell 1 unit at price 37.860000, investment 1.013874 %, total balance 2763.310000,
# day 42, sell 1 unit at price 37.820000, investment 2.382241 %, total balance 2801.130000,
# day 43: buy 1 unit at price 37.870000, total balance 2763.260000
# day 44, sell 1 unit at price 37.600000, investment 1.539292 %, total balance 2800.860000,
# day 46, sell 1 unit at price 37.740000, investment 0.532765 %, total balance 2838.600000,
# day 47: buy 1 unit at price 38.020000, total balance 2800.580000
# day 48: buy 1 unit at price 38.000000, total balance 2762.580000
# day 49, sell 1 unit at price 37.890000, investment 0.557325 %, total balance 2800.470000,
# day 51: buy 1 unit at price 38.150000, total balance 2762.320000
# day 53: buy 1 unit at price 37.850000, total balance 2724.470000
# day 54, sell 1 unit at price 38.150000, investment 0.183824 %, total balance 2762.620000,
# day 55, sell 1 unit at price 37.440000, investment -1.989529 %, total balance 2800.060000,
# day 56, sell 1 unit at price 37.510000, investment -2.241334 %, total balance 2837.570000,
# day 58, sell 1 unit at price 37.900000, investment 0.079218 %, total balance 2875.470000,
# day 60, sell 1 unit at price 38.430000, investment 1.078380 %, total balance 2913.900000,
# day 61, sell 1 unit at price 38.550000, investment 1.447368 %, total balance 2952.450000,
# day 62: buy 1 unit at price 38.460000, total balance 2913.990000
# day 63: buy 1 unit at price 38.670000, total balance 2875.320000
# day 64: buy 1 unit at price 38.070000, total balance 2837.250000
# day 65, sell 1 unit at price 38.470000, investment 0.838794 %, total balance 2875.720000,
# day 67: buy 1 unit at price 38.570000, total balance 2837.150000
# day 69: buy 1 unit at price 38.620000, total balance 2798.530000
# day 70, sell 1 unit at price 38.820000, investment 2.562748 %, total balance 2837.350000,
# day 71, sell 1 unit at price 38.610000, investment 0.390016 %, total balance 2875.960000,
# day 72, sell 1 unit at price 38.710000, investment 0.103439 %, total balance 2914.670000,
# day 73, sell 1 unit at price 38.050000, investment -0.052535 %, total balance 2952.720000,
# day 74: buy 1 unit at price 38.080000, total balance 2914.640000
# day 75: buy 1 unit at price 37.940000, total balance 2876.700000
# day 76, sell 1 unit at price 38.120000, investment -1.166710 %, total balance 2914.820000,
# day 77, sell 1 unit at price 38.140000, investment -1.242879 %, total balance 2952.960000,
# day 78: buy 1 unit at price 38.350000, total balance 2914.610000
# day 79, sell 1 unit at price 38.420000, investment 0.892857 %, total balance 2953.030000,
# day 80: buy 1 unit at price 38.270000, total balance 2914.760000
# day 81, sell 1 unit at price 38.450000, investment 1.344228 %, total balance 2953.210000,
# day 82: buy 1 unit at price 38.440000, total balance 2914.770000
# day 84: buy 1 unit at price 40.290000, total balance 2874.480000
# day 85, sell 1 unit at price 40.200000, investment 4.823990 %, total balance 2914.680000,
# day 86: buy 1 unit at price 39.320000, total balance 2875.360000
# day 87: buy 1 unit at price 40.240000, total balance 2835.120000
# day 88: buy 1 unit at price 40.220000, total balance 2794.900000
# day 89, sell 1 unit at price 40.350000, investment 5.435067 %, total balance 2835.250000,
# day 90, sell 1 unit at price 39.590000, investment 2.991675 %, total balance 2874.840000,
# day 91: buy 1 unit at price 39.720000, total balance 2835.120000
# day 93: buy 1 unit at price 40.300000, total balance 2794.820000
# day 95: buy 1 unit at price 40.430000, total balance 2754.390000
# day 96: buy 1 unit at price 40.940000, total balance 2713.450000
# day 97: buy 1 unit at price 41.030000, total balance 2672.420000
# day 98, sell 1 unit at price 40.350000, investment 0.148920 %, total balance 2712.770000,
# day 99: buy 1 unit at price 40.470000, total balance 2672.300000
# day 100: buy 1 unit at price 40.570000, total balance 2631.730000
# day 101, sell 1 unit at price 39.900000, investment 1.475076 %, total balance 2671.630000,
# day 102, sell 1 unit at price 39.760000, investment -1.192843 %, total balance 2711.390000,
# day 103, sell 1 unit at price 39.720000, investment -1.243163 %, total balance 2751.110000,
# day 104, sell 1 unit at price 39.000000, investment -1.812689 %, total balance 2790.110000,
# day 105, sell 1 unit at price 39.590000, investment -1.761787 %, total balance 2829.700000,
# day 106, sell 1 unit at price 40.110000, investment -0.791491 %, total balance 2869.810000,
# day 107, sell 1 unit at price 40.750000, investment -0.464094 %, total balance 2910.560000,
# day 108, sell 1 unit at price 41.110000, investment 0.194979 %, total balance 2951.670000,
# day 109: buy 1 unit at price 41.280000, total balance 2910.390000
# day 110: buy 1 unit at price 40.990000, total balance 2869.400000
# day 111: buy 1 unit at price 41.270000, total balance 2828.130000
# day 113, sell 1 unit at price 41.260000, investment 1.952063 %, total balance 2869.390000,
# day 114, sell 1 unit at price 40.840000, investment 0.665516 %, total balance 2910.230000,
# day 115: buy 1 unit at price 41.230000, total balance 2869.000000
# day 116, sell 1 unit at price 41.340000, investment 0.145349 %, total balance 2910.340000,
# day 117, sell 1 unit at price 41.570000, investment 1.414979 %, total balance 2951.910000,
# day 119, sell 1 unit at price 41.670000, investment 0.969227 %, total balance 2993.580000,
# day 120: buy 1 unit at price 40.890000, total balance 2952.690000
# day 121, sell 1 unit at price 41.030000, investment -0.485084 %, total balance 2993.720000,
# day 123: buy 1 unit at price 41.200000, total balance 2952.520000
# day 124: buy 1 unit at price 41.360000, total balance 2911.160000
# day 125: buy 1 unit at price 41.880000, total balance 2869.280000
# day 127: buy 1 unit at price 42.000000, total balance 2827.280000
# day 128: buy 1 unit at price 41.830000, total balance 2785.450000
# day 129: buy 1 unit at price 42.450000, total balance 2743.000000
# day 130, sell 1 unit at price 42.560000, investment 4.084128 %, total balance 2785.560000,
# day 131, sell 1 unit at price 42.950000, investment 4.247573 %, total balance 2828.510000,
# day 132, sell 1 unit at price 42.500000, investment 2.756286 %, total balance 2871.010000,
# day 133, sell 1 unit at price 42.750000, investment 2.077364 %, total balance 2913.760000,
# day 134, sell 1 unit at price 42.440000, investment 1.047619 %, total balance 2956.200000,
# day 135, sell 1 unit at price 42.520000, investment 1.649534 %, total balance 2998.720000,
# day 136, sell 1 unit at price 42.680000, investment 0.541814 %, total balance 3041.400000,

# %%
# %matplotlib inline
fig = plt.figure(figsize = (22,10))
plt.plot(close, color='b', lw=2.)
plt.plot(close, '^', markersize=10, color='g', label = 'Buying Signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='r', label = 'Selling Signal', markevery = states_sell)
plt.title('MSFT 2019 Initial Money 3000: Total Investment %f%%'%(invest))
plt.xlabel('Days')
plt.ylabel('Price')
plt.legend()
plt.show()
